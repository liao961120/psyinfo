# 想一想，事情最壞可以多壞？假如那個人成為你的老公，你被內射了幾次，小孩生下後
#
# 你不清楚他失業了沒，反正他不拿錢回家，外面欠一屁股債，還跟外遇對象也生了三個
#
# 外遇對象是越南小吃店的員工，被警察抓到後登上社會版頭條，結果說去驗DNA發現
#
# 還不是你老公的種，所以小孩要被遣返，有人跳出來說你應該扶養這三個小孩
#
# 記者打電話給你，網友肉搜你，名嘴討論你，債主騷擾你
#
#
# 又或者看一下三立或民視的鄉土劇，它們節目收視率好不是沒有原因的，
#
# 因為大多數人的生活中總是可以找到跟劇中情節類似的故事。
#
#
# 這個世界可以很殘忍可可怕的，在那麼多套杯具裡面，你選一個用了八九年之久，
#
# 現在它破了，你把它丟掉正好。有人會為了自己丟掉的垃圾被資源回收婆婆撿回家去用
#
# 而傷心落淚嗎？
#
#
#
# <span class="f2">※ 引述《Qion (珍惜)》之銘言：
# </span><span class="f6">: 在一個人身上花了八九年的時間
# </span><span class="f6">: 因為既有的問題無法解決 關於結婚也無法達成共識
# </span><span class="f6">: 我們分手了
# </span><span class="f6">: 他不到三個月就交了新的 是以前就常一起出國玩
# </span><span class="f6">: 會去接送的人 為什麼是她。。。
# </span><span class="f6">: 現在聽說要結婚(一年多了)
# </span><span class="f6">: 怎麼辦呢我毫無意識的眼淚掉了滿地
# </span><span class="f6">: 這個爛人
# </span><span class="f6">: 共同的朋友不敢告訴我但還是被我知道了
# </span><span class="f6">: 這個人我無法原諒
# </span><span class="f6">: 可是不原諒要怎麼辦 放過自己否則要怎麼過日子?
# </span><span class="f6">: 好想選擇一個容易的 逃避一切痛苦的方法
# </span><span class="f6">: 可是我能嗎?
# </span><span class="f6">: 我這麼努力的 好好活著 重新建立我的生活
# </span><span class="f6">: 一直對抗著不被珍惜的恐懼 被背叛被丟棄的痛苦
# </span><span class="f6">: 可是我的堅強還是被打垮
# </span><span class="f6">: 真的很恨他 如果可以不遇見 該有多好
# </span>
# --
# <span class="f2">※ 發信站: 批踢踢實業坊(ptt.cc)
# </span>◆ From: 172.2.206.224
# <div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">winds19903</span><span class="f3 push-content">:推最後一段</span><span class="push-ipdatetime"> 03/16 19:25
# </span></div></div>
#
#     <div id="article-polling" data-pollurl="/poll/Boy-Girl/M.1394964006.A.850.html?cacheKey=2100-98589289&amp;offset=1501&amp;offset-sig=524863f83251ebdca4f0be5e2b26cbe7059a9c99" data-longpollurl="/v1/longpoll?id=76cff78a4ab7fe3c25ed6ed834e5f07b4ccd1909" data-offset="1501"></div>
#
#
#
# </div>
#
#
#
# <script>
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-32365737-1', {
#     cookieDomain: 'ptt.cc',
#     legacyCookieDomain: 'ptt.cc'
#   });
#   ga('send', 'pageview');
# </script>
#
#
#
# <script src="//ajax.googleapis.com/ajax/libs/jquery/2.1.1/jquery.min.js"></script>
# <script src="//images.ptt.cc/bbs/v2.25/bbs.js"></script>
#
#     </body>
# </html>

# %% [markdown]
# ### 1.2 Basic HTML

# %% [markdown]
# <h1>標1</h1><hr> <h2>標2</hr> <a href="http://ptt.cc">連接</a>
# 這樣<br>可以斷行 <img src="http://bit.ly/1p2za46">
# <center>這樣可以置中和<font color=red>換色</font></center>
# <ul>
# <li><b>粗體</b></li>
# <li><i>斜體</i></li>    <li><u>底線</u></li>
# </ul>
# <table border=1>
# <tr><td>11</td>    <td>12</td></tr>
# <tr><td>21</td>                                   <td>22</td></tr>
# </table>

# %% [markdown]
# ### 1.3 Basic CSS

# %% [markdown]
# #### 1.3.1 CSS not working in Jypyter Notebook

# %% [markdown]
# <style>
# body {color:white; background-color:black;}
# h1 {color:red; font-size:20pt}
# .yy {color:yellow}
# span#gg {color:green}
# div#bb {color:blue}
# </style>
# <h1>Hi!</h1>
# This is <span class=yy>test1</span><hr>
# This is <div class=yy>test2</div><hr>
# This is <span id=gg>test3</span><hr>
# This is <div id=gg>test4</div><hr>
# This is <div id=bb>test5</div><hr>

# %% [markdown]
# #### 1.3.2 CSS working in regular webpages

# %%
from IPython.display import HTML
HTML('<iframe width="560" height="315" src="http://hpc.psy.ntu.edu.tw/info/05/css.html" frameborder="0" allow="autoplay; encrypted-media" allowfullscreen></iframe>')
# Out:
# <iframe width="560" height="315" src="http://hpc.psy.ntu.edu.tw/info/05/css.html" frameborder="0" allow="autoplay; encrypted-media" allowfullscreen></iframe>

# %% [markdown]
# ## 2 Web Crawlers

# %%
# !pip install scrapy

# %% [markdown]
# ### 2.1 LXML & Scrapy
# You can find more about XPath syntax <a href="https://www.w3schools.com/xml/xpath_syntax.asp">here</a>.

# %% [markdown]
# #### 2.1.1 Example 1:
# <p><b>1</b>2<b>3</b></p>

# %%
data='<p><b>1</b>2<b>3</b></p>'

# %% [markdown]
# ##### 2.1.1.1 Using LXML

# %%
import lxml.html
t=lxml.html.fromstring(data)
print(t,t[0],t[0].text,t[1],t[1].text)
# Out:
# <Element p at 0x10a13d1d8> <Element b at 0x10a130098> 1 <Element b at 0x10a130048> 3

# %%
print(t.xpath('//p')[0].text_content()) #123
print(t.xpath('//p')[0].getchildren()) #1,3
print(t.xpath('//b')) #1,3
print(t.xpath('//p/text()')) #2
# Out:
# 123
# [<Element b at 0x10a1309a8>, <Element b at 0x10a1306d8>]
# [<Element b at 0x10a13d228>, <Element b at 0x10a13d278>]
# ['2']

# %% [markdown]
# ##### 2.1.1.2 Using Scrapy Selector

# %%
from scrapy.selector import Selector

# %%
t=Selector(text=data)
print(t)
print(t[0])
# Out:
# <Selector xpath=None data='<html><body><p><b>1</b>2<b>3</b></p></bo'>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-68-0d4dbd459920> in <module>()
#       1 t=Selector(text=data)
#       2 print(t)
# ----> 3 print(t[0])
#
# TypeError: 'Selector' object does not support indexing

# %%
print(t.xpath('//p').extract())
print(t.xpath('//p/text()').extract())
print(t.xpath('//p/text()').extract_first())
print(t.xpath('//p/*').extract())
print(t.xpath('//p').re('\d'))
# Out:
# ['<p><b>1</b>2<b>3</b></p>']
# ['2']
# 2
# ['<b>1</b>', '<b>3</b>']
# ['1', '2', '3']

# %%
print(t.xpath('//b').extract())
print(t.xpath('//b/text()').extract())
print(t.xpath('//b/text()').extract_first())
# Out:
# ['<b>1</b>', '<b>3</b>']
# ['1', '3']
# 1

# %% [markdown]
# #### 2.1.2 Example 2:
# <table>
# <tr><td>11</td><td>12</td></tr>
# <tr><td>21</td><td><a href="http://ptt.cc">22</a></td></tr>
# <tr><td>31</td><td>32</td></tr>
# </table>

# %%
data='''<table>
<tr><td>11</td><td>12</td></tr>
<tr><td>21</td><td><a href="http://ptt.cc">22</a></td></tr>
<tr><td>31</td><td>32</td></tr>
</table>'''

# %% [markdown]
# ##### 2.1.2.1 Using LXML

# %%
t=lxml.html.fromstring(data)
x=t.xpath('//td')
print(x[0].getparent().getnext().getchildren())
print(t.xpath('//a/@href'))
print(t.xpath('//a/text()'))
# Out:
# [<Element td at 0x10a14a688>, <Element td at 0x10a14a638>]
# ['http://ptt.cc']
# ['22']

# %% [markdown]
# ##### 2.1.2.1 Using Scrapy Selector

# %%
print(t.xpath('//td'))
print(t.xpath('//td/..')[1].xpath('*/text()'))
# Out:
# [<Element td at 0x10a14a408>, <Element td at 0x10a14a728>, <Element td at 0x10a14a688>, <Element td at 0x10a14a638>, <Element td at 0x10a14abd8>, <Element td at 0x10a14ac78>]
# ['21']

# %%
print(t.xpath('//a/@href'))
print(t.xpath('//a/text()'))
# Out:
# ['http://ptt.cc']
# ['22']

# %% [markdown]
# #### 2.1.3 Collecting links from PTT

# %% [markdown]
# ##### 2.1.3.1 Using LXML

# %%
u='http://www.ptt.cc/bbs/Boy-Girl/'
h={'User-Agent':'Mozilla/5.0'}
r=urllib.request.Request
[scrapy.utils.log] INFO: Scrapy 1.5.1 started (bot: scrapybot)
# 2018-10-10 17:56:01 [scrapy.utils.log] INFO: Versions: lxml 4.2.1.0, libxml2 2.9.8, cssselect 1.0.3, parsel 1.5.0, w3lib 1.19.0, Twisted 18.7.0, Python 3.6.5 |Anaconda, Inc.| (default, Apr 26 2018, 08:42:37) - [GCC 4.2.1 Compatible Clang 4.0.1 (tags/RELEASE_401/final)], pyOpenSSL 18.0.0 (OpenSSL 1.0.2o  27 Mar 2018), cryptography 2.2.2, Platform Darwin-17.7.0-x86_64-i386-64bit
# 2018-10-10 17:56:01 [scrapy.crawler] INFO: Overridden settings: {'USER_AGENT': 'Mozilla/4.0 (compatible; MSIE 7.0; Windows NT 5.1)'}
# 2018-10-10 17:56:01 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.logstats.LogStats']
# 2018-10-10 17:56:01 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2018-10-10 17:56:01 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2018-10-10 17:56:01 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2018-10-10 17:56:01 [scrapy.core.engine] INFO: Spider opened
# 2018-10-10 17:56:01 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2018-10-10 17:56:01 [scrapy.extensions.telnet] DEBUG: Telnet console listening on 127.0.0.1:6023
# 2018-10-10 17:56:01 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (301) to <GET https://www.ptt.cc/bbs/Boy-Girl/> from <GET http://www.ptt.cc/bbs/Boy-Girl/>
# 2018-10-10 17:56:01 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (302) to <GET https://www.ptt.cc/bbs/Boy-Girl/index.html> from <GET https://www.ptt.cc/bbs/Boy-Girl/>
# 2018-10-10 17:56:01 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.ptt.cc/bbs/Boy-Girl/index.html> (referer: None)
# 2018-10-10 17:56:01 [scrapy.core.engine] INFO: Closing spider (finished)
# 2018-10-10 17:56:01 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 848,
#  'downloader/request_count': 3,
#  'downloader/request_method_count/GET': 3,
#  'downloader/response_bytes': 4079,
#  'downloader/response_count': 3,
#  'downloader/response_status_count/200': 1,
#  'downloader/response_status_count/301': 1,
#  'downloader/response_status_count/302': 1,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2018, 10, 10, 9, 56, 1, 733812),
#  'log_count/DEBUG': 4,
#  'log_count/INFO': 7,
#  'memusage/max': 69541888,
#  'memusage/startup': 69537792,
#  'response_received_count': 1,
#  'scheduler/dequeued': 3,
#  'scheduler/dequeued/memory': 3,
#  'scheduler/enqueued': 3,
#  'scheduler/enqueued/memory': 3,
#  'start_time': datetime.datetime(2018, 10, 10, 9, 56, 1, 352545)}
# 2018-10-10 17:56:01 [scrapy.core.engine] INFO: Spider closed (finished)
# ['批踢踢實業坊']
# ['/bbs/']
# ['Boy-Girl']
# ['/bbs/Boy-Girl/index.html']
# ['關於我們']
# ['/about.html']
# ['聯絡資訊']
# ['/contact.html']
# ['看板']
# ['/bbs/Boy-Girl/index.html']
# ['精華區']
# ['/man/Boy-Girl/index.html']
# ['最舊']
# ['/bbs/Boy-Girl/index1.html']
# ['‹ 上頁']
# ['/bbs/Boy-Girl/index4134.html']
# ['下頁 ›']
# []
# ['最新']
# ['/bbs/Boy-Girl/index.html']
# ['[討論] 大家和另外一半的共同興趣是什麼']
# ['/bbs/Boy-Girl/M.1539148077.A.712.html']
# ['搜尋同標題文章']
# ['/bbs/Boy-Girl/search?q=thread%3A%5B%E8%A8%8E%E8%AB%96%5D+%E5%A4%A7%E5%AE%B6%E5%92%8C%E5%8F%A6%E5%A4%96%E4%B8%80%E5%8D%8A%E7%9A%84%E5%85%B1%E5%90%8C%E8%88%88%E8%B6%A3%E6%98%AF%E4%BB%80%E9%BA%BC']
# ['搜尋看板內 winds6432 的文章']
# ['/bbs/Boy-Girl/search?q=author%3Awinds6432']
# ['[討論] 這種女生該怎麼追']
# ['/bbs/Boy-Girl/M.1539149736.A.060.html']
# ['搜尋同標題文章']
# ['/bbs/Boy-Girl/search?q=thread%3A%5B%E8%A8%8E%E8%AB%96%5D+%E9%80%99%E7%A8%AE%E5%A5%B3%E7%94%9F%E8%A9%B2%E6%80%8E%E9%BA%BC%E8%BF%BD']
# ['搜尋看板內 q10242 的文章']
# ['/bbs/Boy-Girl/search?q=author%3Aq10242']
# ['[求助] 不知道該怎樣面對這趟旅遊']
# ['/bbs/Boy-Girl/M.1539155405.A.9D3.html']
# ['搜尋同標題文章']
# ['/bbs/Boy-Girl/search?q=thread%3A%5B%E6%B1%82%E5%8A%A9%5D+%E4%B8%8D%E7%9F%A5%E9%81%93%E8%A9%B2%E6%80%8E%E6%A8%A3%E9%9D%A2%E5%B0%8D%E9%80%99%E8%B6%9F%E6%97%85%E9%81%8A']
# ['搜尋看板內 victor7198 的文章']
# ['/bbs/Boy-Girl/search?q=author%3Avictor7198']
# ['[求助] 溝通問題有解嗎？']
# ['/bbs/Boy-Girl/M.1539157011.A.A51.html']
# ['搜尋同標題文章']
# ['/bbs/Boy-Girl/search?q=thread%3A%5B%E6%B1%82%E5%8A%A9%5D+%E6%BA%9D%E9%80%9A%E5%95%8F%E9%A1%8C%E6%9C%89%E8%A7%A3%E5%97%8E%EF%BC%9F']
# ['搜尋看板內 bluefinger 的文章']
# ['/bbs/Boy-Girl/search?q=author%3Abluefinger']
# ['Re: [求助] 不知道該怎麼走出來']
# ['/bbs/Boy-Girl/M.1539159187.A.C5F.html']
# ['搜尋同標題文章']
# ['/bbs/Boy-Girl/search?q=thread%3A%5B%E6%B1%82%E5%8A%A9%5D+%E4%B8%8D%E7%9F%A5%E9%81%93%E8%A9%B2%E6%80%8E%E9%BA%BC%E8%B5%B0%E5%87%BA%E4%BE%86']
# ['搜尋看板內 ryantikoe 的文章']
# ['/bbs/Boy-Girl/search?q=author%3Aryantikoe']
# ['[討論] 遠距離講電話/視訊的頻率？']
# ['/bbs/Boy-Girl/M.1539164816.A.9A9.html']
# ['搜尋同標題文章']
# ['/bbs/Boy-Girl/search?q=thread%3A%5B%E8%A8%8E%E8%AB%96%5D+%E9%81%A0%E8%B7%9D%E9%9B%A2%E8%AC%9B%E9%9B%BB%E8%A9%B1%2F%E8%A6%96%E8%A8%8A%E7%9A%84%E9%A0%BB%E7%8E%87%EF%BC%9F']
# ['搜尋看板內 zolo1122 的文章']
# ['/bbs/Boy-Girl/search?q=author%3Azolo1122']
# ['[公告] 2014/05/11新制板規（必讀）']
# ['/bbs/Boy-Girl/M.1399745290.A.6F3.html']
# ['搜尋同標題文章']
# ['/bbs/Boy-Girl/search?q=thread%3A%5B%E5%85%AC%E5%91%8A%5D+2014%2F05%2F11%E6%96%B0%E5%88%B6%E6%9D%BF%E8%A6%8F%EF%BC%88%E5%BF%85%E8%AE%80%EF%BC%89']
# ['搜尋看板內 snda 的文章']
# ['/bbs/Boy-Girl/search?q=author%3Asnda']
# ['[公告] 關於新制板規說明（必讀）']
# ['/bbs/Boy-Girl/M.1399818891.A.D72.html']
# ['搜尋同標題文章']
# ['/bbs/Boy-Girl/search?q=thread%3A%5B%E5%85%AC%E5%91%8A%5D+%E9%97%9C%E6%96%BC%E6%96%B0%E5%88%B6%E6%9D%BF%E8%A6%8F%E8%AA%AA%E6%98%8E%EF%BC%88%E5%BF%85%E8%AE%80%EF%BC%89']
# ['搜尋看板內 snda 的文章']
# ['/bbs/Boy-Girl/search?q=author%3Asnda']
# ['[公告] 分身帳號違規條款啟動']
# ['/bbs/Boy-Girl/M.1434215804.A.C8D.html']
# ['搜尋同標題文章']
# ['/bbs/Boy-Girl/search?q=thread%3A%5B%E5%85%AC%E5%91%8A%5D+%E5%88%86%E8%BA%AB%E5%B8%B3%E8%99%9F%E9%81%95%E8%A6%8F%E6%A2%9D%E6%AC%BE%E5%95%9F%E5%8B%95']
# ['搜尋看板內 idlechild 的文章']
# ['/bbs/Boy-Girl/search?q=author%3Aidlechild']
# ['[閒聊] 2018/09/14 置底閒聊區']
# ['/bbs/Boy-Girl/M.1536922729.A.31C.html']
# ['搜尋同標題文章']
# ['/bbs/Boy-Girl/search?q=thread%3A%5B%E9%96%92%E8%81%8A%5D+2018%2F09%2F14+%E7%BD%AE%E5%BA%95%E9%96%92%E8%81%8A%E5%8D%80']
# ['搜尋看板內 darkfool 的文章']
# ['/bbs/Boy-Girl/search?q=author%3Adarkfool']

# %% [markdown]
# #### 2.1.4 Analyzing texts from PTT

# %% [markdown]
# ##### 2.1.4.1 Using LXML

# %%
import urllib, lxml.html
URL='http://www.ptt.cc'
URN='/bbs/Boy-Girl/M.1394964006.A.850.html'
h={'User-Agent':'Mozilla/5.0'}
r=urllib.request.Request(URL+URN,headers=h)
data=urllib.request.urlopen(r).read()
t=lxml.html.fromstring(data.decode('utf-8'))
print(t.text_content()) #整頁
# Out:
#
#
#
#
#
#
# Re: [心情] 我要怎麼原諒那個人 - 看板 Boy-Girl - 批踢踢實業坊
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# (function(d, s, id) {
# var js, fjs = d.getElementsByTagName(s)[0];
# if (d.getElementById(id)) return;
# js = d.createElement(s); js.id = id;
# js.src = "//connect.facebook.net/en_US/all.js#xfbml=1";
# fjs.parentNode.insertBefore(js, fjs);
# }(document, 'script', 'facebook-jssdk'));
#
#
#
# 		批踢踢實業坊
# 		›
# 		看板 Boy-Girl
# 		關於我們
# 		聯絡資訊
#
#
#
#
# 		返回看板
#
#
# 			分享
#
#
#
#
# window.___gcfg = {lang: 'zh-TW'};
# (function() {
# var po = document.createElement('script'); po.type = 'text/javascript'; po.async = true;
# po.src = 'https://apis.google.com/js/plusone.js';
# var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(po, s);
# })();
#
#
#
#
#
#
#     作者wbson (Simple Power)站內Boy-Girl標題Re: [心情] 我要怎麼原諒那個人時間Sun Mar 16 18:00:03 2014
# 想一想，事情最壞可以多壞？假如那個人成為你的老公，你被內射了幾次，小孩生下後
#
# 你不清楚他失業了沒，反正他不拿錢回家，外面欠一屁股債，還跟外遇對象也生了三個
#
# 外遇對象是越南小吃店的員工，被警察抓到後登上社會版頭條，結果說去驗DNA發現
#
# 還不是你老公的種，所以小孩要被遣返，有人跳出來說你應該扶養這三個小孩
#
# 記者打電話給你，網友肉搜你，名嘴討論你，債主騷擾你
#
#
# 又或者看一下三立或民視的鄉土劇，它們節目收視率好不是沒有原因的，
#
# 因為大多數人的生活中總是可以找到跟劇中情節類似的故事。
#
#
# 這個世界可以很殘忍可可怕的，在那麼多套杯具裡面，你選一個用了八九年之久，
#
# 現在它破了，你把它丟掉正好。有人會為了自己丟掉的垃圾被資源回收婆婆撿回家去用
#
# 而傷心落淚嗎？
#
#
#
# ※ 引述《Qion (珍惜)》之銘言：
# : 在一個人身上花了八九年的時間
# : 因為既有的問題無法解決 關於結婚也無法達成共識
# : 我們分手了
# : 他不到三個月就交了新的 是以前就常一起出國玩
# : 會去接送的人 為什麼是她。。。
# : 現在聽說要結婚(一年多了)
# : 怎麼辦呢我毫無意識的眼淚掉了滿地
# : 這個爛人
# : 共同的朋友不敢告訴我但還是被我知道了
# : 這個人我無法原諒
# : 可是不原諒要怎麼辦 放過自己否則要怎麼過日子?
# : 好想選擇一個容易的 逃避一切痛苦的方法
# : 可是我能嗎?
# : 我這麼努力的 好好活著 重新建立我的生活
# : 一直對抗著不被珍惜的恐懼 被背叛被丟棄的痛苦
# : 可是我的堅強還是被打垮
# : 真的很恨他 如果可以不遇見 該有多好
#
# --
# ※ 發信站: 批踢踢實業坊(ptt.cc)
# ◆ From: 172.2.206.224
# 推 winds19903:推最後一段 03/16 19:25
#
#
#
#
#
#
#
#
#
#
#
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-32365737-1', {
#     cookieDomain: 'ptt.cc',
#     legacyCookieDomain: 'ptt.cc'
#   });
#   ga('send', 'pageview');

# %%
x=t.xpath('//div[@id="main-content"]')[0]
print(x.text_content()) #主文
# Out:
# 作者wbson (Simple Power)站內Boy-Girl標題Re: [心情] 我要怎麼原諒那個人時間Sun Mar 16 18:00:03 2014
# 想一想，事情最壞可以多壞？假如那個人成為你的老公，你被內射了幾次，小孩生下後
#
# 你不清楚他失業了沒，反正他不拿錢回家，外面欠一屁股債，還跟外遇對象也生了三個
#
# 外遇對象是越南小吃店的員工，被警察抓到後登上社會版頭條，結果說去驗DNA發現
#
# 還不是你老公的種，所以小孩要被遣返，有人跳出來說你應該扶養這三個小孩
#
# 記者打電話給你，網友肉搜你，名嘴討論你，債主騷擾你
#
#
# 又或者看一下三立或民視的鄉土劇，它們節目收視率好不是沒有原因的，
#
# 因為大多數人的生活中總是可以找到跟劇中情節類似的故事。
#
#
# 這個世界可以很殘忍可可怕的，在那麼多套杯具裡面，你選一個用了八九年之久，
#
# 現在它破了，你把它丟掉正好。有人會為了自己丟掉的垃圾被資源回收婆婆撿回家去用
#
# 而傷心落淚嗎？
#
#
#
# ※ 引述《Qion (珍惜)》之銘言：
# : 在一個人身上花了八九年的時間
# : 因為既有的問題無法解決 關於結婚也無法達成共識
# : 我們分手了
# : 他不到三個月就交了新的 是以前就常一起出國玩
# : 會去接送的人 為什麼是她。。。
# : 現在聽說要結婚(一年多了)
# : 怎麼辦呢我毫無意識的眼淚掉了滿地
# : 這個爛人
# : 共同的朋友不敢告訴我但還是被我知道了
# : 這個人我無法原諒
# : 可是不原諒要怎麼辦 放過自己否則要怎麼過日子?
# : 好想選擇一個容易的 逃避一切痛苦的方法
# : 可是我能嗎?
# : 我這麼努力的 好好活著 重新建立我的生活
# : 一直對抗著不被珍惜的恐懼 被背叛被丟棄的痛苦
# : 可是我的堅強還是被打垮
# : 真的很恨他 如果可以不遇見 該有多好
#
# --
# ※ 發信站: 批踢踢實業坊(ptt.cc)
# ◆ From: 172.2.206.224
# 推 winds19903:推最後一段 03/16 19:25

# %%
y=t.xpath('//div[@id="main-content"]/text()')
print(''.join(y)) #新文
# Out:
# 想一想，事情最壞可以多壞？假如那個人成為你的老公，你被內射了幾次，小孩生下後
#
# 你不清楚他失業了沒，反正他不拿錢回家，外面欠一屁股債，還跟外遇對象也生了三個
#
# 外遇對象是越南小吃店的員工，被警察抓到後登上社會版頭條，結果說去驗DNA發現
#
# 還不是你老公的種，所以小孩要被遣返，有人跳出來說你應該扶養這三個小孩
#
# 記者打電話給你，網友肉搜你，名嘴討論你，債主騷擾你
#
#
# 又或者看一下三立或民視的鄉土劇，它們節目收視率好不是沒有原因的，
#
# 因為大多數人的生活中總是可以找到跟劇中情節類似的故事。
#
#
# 這個世界可以很殘忍可可怕的，在那麼多套杯具裡面，你選一個用了八九年之久，
#
# 現在它破了，你把它丟掉正好。有人會為了自己丟掉的垃圾被資源回收婆婆撿回家去用
#
# 而傷心落淚嗎？
#
#
#
#
# --
# ◆ From: 172.2.206.224

# %%
z=t.xpath('//span[@class="f6"]')
for i in z:
 print(i.text) #引言
# Out:
# : 在一個人身上花了八九年的時間
#
# : 因為既有的問題無法解決 關於結婚也無法達成共識
#
# : 我們分手了
#
# : 他不到三個月就交了新的 是以前就常一起出國玩
#
# : 會去接送的人 為什麼是她。。。
#
# : 現在聽說要結婚(一年多了)
#
# : 怎麼辦呢我毫無意識的眼淚掉了滿地
#
# : 這個爛人
#
# : 共同的朋友不敢告訴我但還是被我知道了
#
# : 這個人我無法原諒
#
# : 可是不原諒要怎麼辦 放過自己否則要怎麼過日子?
#
# : 好想選擇一個容易的 逃避一切痛苦的方法
#
# : 可是我能嗎?
#
# : 我這麼努力的 好好活著 重新建立我的生活
#
# : 一直對抗著不被珍惜的恐懼 被背叛被丟棄的痛苦
#
# : 可是我的堅強還是被打垮
#
# : 真的很恨他 如果可以不遇見 該有多好

# %%
H=t.xpath('//*[contains(text(),"恨")]')[0]
print(H.text) #含恨
# Out:
# : 真的很恨他 如果可以不遇見 該有多好

# %% [markdown]
# ##### 2.1.4.2 Using Scrapy

# %%
import scrapy
from scrapy.crawler import CrawlerProcess

# %%
class Spider0(scrapy.Spider): #source
    name="ptt"
    start_urls=["http://www.ptt.cc/bbs/Boy-Girl/M.1394964006.A.850.html"]
    def parse(self, response):
        print(response.text)
        
class Spider1(scrapy.Spider): #body
    name="ptt"
    start_urls=["http://www.ptt.cc/bbs/Boy-Girl/M.1394964006.A.850.html"]
    def parse(self, response):
        print(''.join(response.xpath("//body//text()").extract()))
        
class Spider2(scrapy.Spider): #新文
    name="ptt"
    start_urls=["http://www.ptt.cc/bbs/Boy-Girl/M.1394964006.A.850.html"]
    def parse(self, response):
        print(response.xpath('//div[@id="main-content"]/text()').extract()[0].strip())

class Spider3(scrapy.Spider): #引言
    name="ptt"
    start_urls=["http://www.ptt.cc/bbs/Boy-Girl/M.1394964006.A.850.html"]
    def parse(self, response):
        print(''.join(response.xpath('//span[@class="f6"]/text()').extract()))
        
class Spider4(scrapy.Spider): #含恨
    name="ptt"
    start_urls=["http://www.ptt.cc/bbs/Boy-Girl/M.1394964006.A.850.html"]
    def parse(self, response):
        print(response.xpath('//*[contains(text(),"恨")]/text()').extract())

# %%
process = CrawlerProcess()
process.crawl(Spider0)
process.start()
# Out:
# 2018-10-10 20:22:58 [scrapy.utils.log] INFO: Scrapy 1.5.1 started (bot: scrapybot)
# 2018-10-10 20:22:58 [scrapy.utils.log] INFO: Versions: lxml 4.2.1.0, libxml2 2.9.8, cssselect 1.0.3, parsel 1.5.0, w3lib 1.19.0, Twisted 18.7.0, Python 3.6.5 |Anaconda, Inc.| (default, Apr 26 2018, 08:42:37) - [GCC 4.2.1 Compatible Clang 4.0.1 (tags/RELEASE_401/final)], pyOpenSSL 18.0.0 (OpenSSL 1.0.2o  27 Mar 2018), cryptography 2.2.2, Platform Darwin-17.7.0-x86_64-i386-64bit
# 2018-10-10 20:22:58 [scrapy.crawler] INFO: Overridden settings: {}
# 2018-10-10 20:22:58 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.logstats.LogStats']
# 2018-10-10 20:22:59 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2018-10-10 20:22:59 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2018-10-10 20:22:59 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2018-10-10 20:22:59 [scrapy.core.engine] INFO: Spider opened
# 2018-10-10 20:22:59 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2018-10-10 20:22:59 [scrapy.extensions.telnet] DEBUG: Telnet console listening on 127.0.0.1:6023
# 2018-10-10 20:22:59 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (301) to <GET https://www.ptt.cc/bbs/Boy-Girl/M.1394964006.A.850.html> from <GET http://www.ptt.cc/bbs/Boy-Girl/M.1394964006.A.850.html>
# 2018-10-10 20:22:59 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.ptt.cc/bbs/Boy-Girl/M.1394964006.A.850.html> (referer: None)
# 2018-10-10 20:22:59 [scrapy.core.engine] INFO: Closing spider (finished)
# 2018-10-10 20:22:59 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 552,
#  'downloader/request_count': 2,
#  'downloader/request_method_count/GET': 2,
#  'downloader/response_bytes': 4310,
#  'downloader/response_count': 2,
#  'downloader/response_status_count/200': 1,
#  'downloader/response_status_count/301': 1,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2018, 10, 10, 12, 22, 59, 753312),
#  'log_count/DEBUG': 3,
#  'log_count/INFO': 7,
#  'memusage/max': 69537792,
#  'memusage/startup': 69537792,
#  'response_received_count': 1,
#  'scheduler/dequeued': 2,
#  'scheduler/dequeued/memory': 2,
#  'scheduler/enqueued': 2,
#  'scheduler/enqueued/memory': 2,
#  'start_time': datetime.datetime(2018, 10, 10, 12, 22, 59, 79064)}
# 2018-10-10 20:22:59 [scrapy.core.engine] INFO: Spider closed (finished)
# <!DOCTYPE html>
# <html>
# 	<head>
# 		<meta charset="utf-8">
#
#
# <meta name="viewport" content="width=device-width, initial-scale=1">
#
# <title>Re: [心情] 我要怎麼原諒那個人 - 看板 Boy-Girl - 批踢踢實業坊</title>
# <meta name="robots" content="all">
# <meta name="keywords" content="Ptt BBS 批踢踢">
# <meta name="description" content="想一想，事情最壞可以多壞？假如那個人成為你的老公，你被內射了幾次，小孩生下後
# 你不清楚他失業了沒，反正他不拿錢回家，外面欠一屁股債，還跟外遇對象也生了三個
# 外遇對象是越南小吃店的員工，被警察抓到後登上社會版頭條，結果說去驗DNA發現
# 還不是你老公的種，所以小孩要被遣返，有人跳出來說你應該扶養這三個小孩
# 記者打電話給你，網友肉搜你，名嘴討論你，債主騷擾你
# ">
# <meta property="og:site_name" content="Ptt 批踢踢實業坊">
# <meta property="og:title" content="Re: [心情] 我要怎麼原諒那個人">
# <meta property="og:description" content="想一想，事情最壞可以多壞？假如那個人成為你的老公，你被內射了幾次，小孩生下後
# 你不清楚他失業了沒，反正他不拿錢回家，外面欠一屁股債，還跟外遇對象也生了三個
# 外遇對象是越南小吃店的員工，被警察抓到後登上社會版頭條，結果說去驗DNA發現
# 還不是你老公的種，所以小孩要被遣返，有人跳出來說你應該扶養這三個小孩
# 記者打電話給你，網友肉搜你，名嘴討論你，債主騷擾你
# ">
# <link rel="canonical" href="https://www.ptt.cc/bbs/Boy-Girl/M.1394964006.A.850.html">
#
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.25/bbs-common.css">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.25/bbs-base.css" media="screen">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.25/bbs-custom.css">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.25/pushstream.css" media="screen">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.25/bbs-print.css" media="print">
#
#
#
#
# 	</head>
#     <body>
#
# <div id="fb-root"></div>
# <script>(function(d, s, id) {
# var js, fjs = d.getElementsByTagName(s)[0];
# if (d.getElementById(id)) return;
# js = d.createElement(s); js.id = id;
# js.src = "//connect.facebook.net/en_US/all.js#xfbml=1";
# fjs.parentNode.insertBefore(js, fjs);
# }(document, 'script', 'facebook-jssdk'));</script>
#
# <div id="topbar-container">
# 	<div id="topbar" class="bbs-content">
# 		<a id="logo" href="/bbs/">批踢踢實業坊</a>
# 		<span>&rsaquo;</span>
# 		<a class="board" href="/bbs/Boy-Girl/index.html"><span class="board-label">看板 </span>Boy-Girl</a>
# 		<a class="right small" href="/about.html">關於我們</a>
# 		<a class="right small" href="/contact.html">聯絡資訊</a>
# 	</div>
# </div>
# <div id="navigation-container">
# 	<div id="navigation" class="bbs-content">
# 		<a class="board" href="/bbs/Boy-Girl/index.html">返回看板</a>
# 		<div class="bar"></div>
# 		<div class="share">
# 			<span>分享</span>
# 			<div class="fb-like" data-send="false" data-layout="button_count" data-width="90" data-show-faces="false" data-href="http://www.ptt.cc/bbs/Boy-Girl/M.1394964006.A.850.html"></div>
#
# 			<div class="g-plusone" data-size="medium"></div>
# <script type="text/javascript">
# window.___gcfg = {lang: 'zh-TW'};
# (function() {
# var po = document.createElement('script'); po.type = 'text/javascript'; po.async = true;
# po.src = 'https://apis.google.com/js/plusone.js';
# var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(po, s);
# })();
# </script>
#
# 		</div>
# 	</div>
# </div>
# <div id="main-container">
#     <div id="main-content" class="bbs-screen bbs-content"><div class="article-metaline"><span class="article-meta-tag">作者</span><span class="article-meta-value">wbson (Simple Power)</span></div><div class="article-metaline-right"><span class="article-meta-tag">站內</span><span class="article-meta-value">Boy-Girl</span></div><div class="article-metaline"><span class="article-meta-tag">標題</span><span class="article-meta-value">Re: [心情] 我要怎麼原諒那個人</span></div><div class="article-metaline"><span class="article-meta-tag">時間</span><span class="article-meta-value">Sun Mar 16 18:00:03 2014</span></div>
# 想一想，事情最壞可以多壞？假如那個人成為你的老公，你被內射了幾次，小孩生下後
#
# 你不清楚他失業了沒，反正他不拿錢回家，外面欠一屁股債，還跟外遇對象也生了三個
#
# 外遇對象是越南小吃店的員工，被警察抓到後登上社會版頭條，結果說去驗DNA發現
#
# 還不是你老公的種，所以小孩要被遣返，有人跳出來說你應該扶養這三個小孩
#
# 記者打電話給你，網友肉搜你，名嘴討論你，債主騷擾你
#
#
# 又或者看一下三立或民視的鄉土劇，它們節目收視率好不是沒有原因的，
#
# 因為大多數人的生活中總是可以找到跟劇中情節類似的故事。
#
#
# 這個世界可以很殘忍可可怕的，在那麼多套杯具裡面，你選一個用了八九年之久，
#
# 現在它破了，你把它丟掉正好。有人會為了自己丟掉的垃圾被資源回收婆婆撿回家去用
#
# 而傷心落淚嗎？
#
#
#
# <span class="f2">※ 引述《Qion (珍惜)》之銘言：
# </span><span class="f6">: 在一個人身上花了八九年的時間
# </span><span class="f6">: 因為既有的問題無法解決 關於結婚也無法達成共識
# </span><span class="f6">: 我們分手了
# </span><span class="f6">: 他不到三個月就交了新的 是以前就常一起出國玩
# </span><span class="f6">: 會去接送的人 為什麼是她。。。
# </span><span class="f6">: 現在聽說要結婚(一年多了)
# </span><span class="f6">: 怎麼辦呢我毫無意識的眼淚掉了滿地
# </span><span class="f6">: 這個爛人
# </span><span class="f6">: 共同的朋友不敢告訴我但還是被我知道了
# </span><span class="f6">: 這個人我無法原諒
# </span><span class="f6">: 可是不原諒要怎麼辦 放過自己否則要怎麼過日子?
# </span><span class="f6">: 好想選擇一個容易的 逃避一切痛苦的方法
# </span><span class="f6">: 可是我能嗎?
# </span><span class="f6">: 我這麼努力的 好好活著 重新建立我的生活
# </span><span class="f6">: 一直對抗著不被珍惜的恐懼 被背叛被丟棄的痛苦
# </span><span class="f6">: 可是我的堅強還是被打垮
# </span><span class="f6">: 真的很恨他 如果可以不遇見 該有多好
# </span>
# --
# <span class="f2">※ 發信站: 批踢踢實業坊(ptt.cc)
# </span>◆ From: 172.2.206.224
# <div class="push"><span class="hl push-tag">推 </span><span class="f3 hl push-userid">winds19903</span><span class="f3 push-content">:推最後一段</span><span class="push-ipdatetime"> 03/16 19:25
# </span></div></div>
#
#     <div id="article-polling" data-pollurl="/poll/Boy-Girl/M.1394964006.A.850.html?cacheKey=2100-98589289&amp;offset=1501&amp;offset-sig=524863f83251ebdca4f0be5e2b26cbe7059a9c99" data-longpollurl="/v1/longpoll?id=76cff78a4ab7fe3c25ed6ed834e5f07b4ccd1909" data-offset="1501"></div>
#
#
#
# </div>
#
#
#
# <script>
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-32365737-1', {
#     cookieDomain: 'ptt.cc',
#     legacyCookieDomain: 'ptt.cc'
#   });
#   ga('send', 'pageview');
# </script>
#
#
#
# <script src="//ajax.googleapis.com/ajax/libs/jquery/2.1.1/jquery.min.js"></script>
# <script src="//images.ptt.cc/bbs/v2.25/bbs.js"></script>
#
#     </body>
# </html>

# %% [markdown]
# #### 2.1.4 Sending HTML forms

# %% [markdown]
# ##### 2.1.4.1 Using urllib

# %%
# Not working without sending required info:
import urllib.request 
u='http://www.ptt.cc/bbs/Gossiping/'
h={'User-Agent':'Mozilla/5.0'}
r=urllib.request.Request(u,headers=h)
data=urllib.request.urlopen(r).read()
print(data.decode('utf-8'))
# Out:
# <!DOCTYPE html>
# <html>
# 	<head>
# 		<meta charset="utf-8">
#
#
# <meta name="viewport" content="width=device-width, initial-scale=1">
#
# <title>批踢踢實業坊</title>
#
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.25/bbs-common.css">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.25/bbs-base.css" media="screen">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.25/bbs-custom.css">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.25/pushstream.css" media="screen">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.25/bbs-print.css" media="print">
#
#
#
#
# 	</head>
#     <body>
#
# <div class="bbs-screen bbs-content">
#     <div class="over18-notice">
#         <p>本網站已依網站內容分級規定處理</p>
#
#         <p>警告︰您即將進入之看板內容需滿十八歲方可瀏覽。</p>
#
#         <p>若您尚未年滿十八歲，請點選離開。若您已滿十八歲，亦不可將本區之內容派發、傳閱、出售、出租、交給或借予年齡未滿18歲的人士瀏覽，或將本網站內容向該人士出示、播放或放映。</p>
#     </div>
# </div>
#
# <div class="bbs-screen bbs-content center clear">
#     <form action="/ask/over18" method="post">
#         <input type="hidden" name="from" value="/bbs/Gossiping/index.html">
#         <div class="over18-button-container">
#             <button class="btn-big" type="submit" name="yes" value="yes">我同意，我已年滿十八歲<br><small>進入</small></button>
#         </div>
#         <div class="over18-button-container">
#             <button class="btn-big" type="submit" name="no" value="no">未滿十八歲或不同意本條款<br><small>離開</small></button>
#         </div>
#     </form>
# </div>
#
#
#
# <script>
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-32365737-1', {
#     cookieDomain: 'ptt.cc',
#     legacyCookieDomain: 'ptt.cc'
#   });
#   ga('send', 'pageview');
# </script>
#
#
#
# <script src="//ajax.googleapis.com/ajax/libs/jquery/2.1.1/jquery.min.js"></script>
# <script src="//images.ptt.cc/bbs/v2.25/bbs.js"></script>
#
#     </body>
# </html>

# %%
# Still not working even with required information:
from urllib import parse,request
URL='https://www.ptt.cc'
URN='/ask/over18'
q=parse.urlencode({'yes':'yes','from':'/bbs/Gossiping/'})
q=q.encode('utf-8')
h={'User-Agent':'Mozilla/5.0'}
req=request.Request(URL+URN,q,h)
response=request.urlopen(req)
data=response.read()
print(data.decode('utf-8'))
# Out:
# <!DOCTYPE html>
# <html>
# 	<head>
# 		<meta charset="utf-8">
#
#
# <meta name="viewport" content="width=device-width, initial-scale=1">
#
# <title>批踢踢實業坊</title>
#
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.25/bbs-common.css">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.25/bbs-base.css" media="screen">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.25/bbs-custom.css">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.25/pushstream.css" media="screen">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.25/bbs-print.css" media="print">
#
#
#
#
# 	</head>
#     <body>
#
# <div class="bbs-screen bbs-content">
#     <div class="over18-notice">
#         <p>本網站已依網站內容分級規定處理</p>
#
#         <p>警告︰您即將進入之看板內容需滿十八歲方可瀏覽。</p>
#
#         <p>若您尚未年滿十八歲，請點選離開。若您已滿十八歲，亦不可將本區之內容派發、傳閱、出售、出租、交給或借予年齡未滿18歲的人士瀏覽，或將本網站內容向該人士出示、播放或放映。</p>
#     </div>
# </div>
#
# <div class="bbs-screen bbs-content center clear">
#     <form action="/ask/over18" method="post">
#         <input type="hidden" name="from" value="/bbs/Gossiping/index.html">
#         <div class="over18-button-container">
#             <button class="btn-big" type="submit" name="yes" value="yes">我同意，我已年滿十八歲<br><small>進入</small></button>
#         </div>
#         <div class="over18-button-container">
#             <button class="btn-big" type="submit" name="no" value="no">未滿十八歲或不同意本條款<br><small>離開</small></button>
#         </div>
#     </form>
# </div>
#
#
#
# <script>
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-32365737-1', {
#     cookieDomain: 'ptt.cc',
#     legacyCookieDomain: 'ptt.cc'
#   });
#   ga('send', 'pageview');
# </script>
#
#
#
# <script src="//ajax.googleapis.com/ajax/libs/jquery/2.1.1/jquery.min.js"></script>
# <script src="//images.ptt.cc/bbs/v2.25/bbs.js"></script>
#
#     </body>
# </html>

# %%
# Working version with a cookie set:
from urllib import parse,request
URL='https://www.ptt.cc'
URN='/ask/over18'
q=parse.urlencode({'yes':'yes','from':'/bbs/Gossiping/'})
q=q.encode('utf-8')
h={'Cookie':'over18=1','User-Agent':'Mozilla/5.0'}
req=request.Request(URL+URN,q,h)
response=request.urlopen(req)
data=response.read()
print(data.decode('utf-8'))
# Out:
# <!DOCTYPE html>
# <html>
# 	<head>
# 		<meta charset="utf-8">
#
#
# <meta name="viewport" content="width=device-width, initial-scale=1">
#
# <title>看板 Gossiping 文章列表 - 批踢踢實業坊</title>
#
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.25/bbs-common.css">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.25/bbs-base.css" media="screen">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.25/bbs-custom.css">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.25/pushstream.css" media="screen">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.25/bbs-print.css" media="print">
#
#
#
#
# 	</head>
#     <body>
#
# <div id="topbar-container">
# 	<div id="topbar" class="bbs-content">
# 		<a id="logo" href="/bbs/">批踢踢實業坊</a>
# 		<span>&rsaquo;</span>
# 		<a class="board" href="/bbs/Gossiping/index.html"><span class="board-label">看板 </span>Gossiping</a>
# 		<a class="right small" href="/about.html">關於我們</a>
# 		<a class="right small" href="/contact.html">聯絡資訊</a>
# 	</div>
# </div>
#
# <div id="main-container">
# 	<div id="action-bar-container">
# 		<div class="action-bar">
# 			<div class="btn-group btn-group-dir">
# 				<a class="btn selected" href="/bbs/Gossiping/index.html">看板</a>
# 				<a class="btn" href="/man/Gossiping/index.html">精華區</a>
# 			</div>
# 			<div class="btn-group btn-group-paging">
# 				<a class="btn wide" href="/bbs/Gossiping/index1.html">最舊</a>
# 				<a class="btn wide" href="/bbs/Gossiping/index39197.html">&lsaquo; 上頁</a>
# 				<a class="btn wide disabled">下頁 &rsaquo;</a>
# 				<a class="btn wide" href="/bbs/Gossiping/index.html">最新</a>
# 			</div>
# 		</div>
# 	</div>
#
# 	<div class="r-list-container action-bar-margin bbs-screen">
# 		<div class="search-bar">
# 			<form type="get" action="search" id="search-bar">
# 				<input class="query" type="text" name="q" value="" placeholder="搜尋文章&#x22ef;">
# 			</form>
# 		</div>
#
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f2">2</span></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1539173853.A.007.html">[問卦] 很煩躁時該如何解決？</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">zakijudelo</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%95%8F%E5%8D%A6%5D&#43;%E5%BE%88%E7%85%A9%E8%BA%81%E6%99%82%E8%A9%B2%E5%A6%82%E4%BD%95%E8%A7%A3%E6%B1%BA%EF%BC%9F">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Gossiping/search?q=author%3Azakijudelo">搜尋看板內 zakijudelo 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date">10/10</div>
# 				<div class="mark"></div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f2">4</span></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1539173886.A.3ED.html">[問卦] 第一次跟肥宅做愛該注意什麼？</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">ex250203</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%95%8F%E5%8D%A6%5D&#43;%E7%AC%AC%E4%B8%80%E6%AC%A1%E8%B7%9F%E8%82%A5%E5%AE%85%E5%81%9A%E6%84%9B%E8%A9%B2%E6%B3%A8%E6%84%8F%E4%BB%80%E9%BA%BC%EF%BC%9F">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Gossiping/search?q=author%3Aex250203">搜尋看板內 ex250203 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date">10/10</div>
# 				<div class="mark"></div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1539173921.A.8B8.html">[問卦] 被服務會通體舒暢是甚麼原理?</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">x04nonesuchx</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%95%8F%E5%8D%A6%5D&#43;%E8%A2%AB%E6%9C%8D%E5%8B%99%E6%9C%83%E9%80%9A%E9%AB%94%E8%88%92%E6%9A%A2%E6%98%AF%E7%94%9A%E9%BA%BC%E5%8E%9F%E7%90%86%3F">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Gossiping/search?q=author%3Ax04nonesuchx">搜尋看板內 x04nonesuchx 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date">10/10</div>
# 				<div class="mark"></div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1539173933.A.0F9.html">[新聞]柯Ｐ缺席青年論壇 錕P：連被檢驗的勇氣</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">qooisgood</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E6%96%B0%E8%81%9E%5D%E6%9F%AF%EF%BC%B0%E7%BC%BA%E5%B8%AD%E9%9D%92%E5%B9%B4%E8%AB%96%E5%A3%87&#43;%E9%8C%95P%EF%BC%9A%E9%80%A3%E8%A2%AB%E6%AA%A2%E9%A9%97%E7%9A%84%E5%8B%87%E6%B0%A3">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Gossiping/search?q=author%3Aqooisgood">搜尋看板內 qooisgood 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date">10/10</div>
# 				<div class="mark"></div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1539173939.A.E92.html">[問卦] 延禧攻略看不下去怎麼辦?</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">Tiiek</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%95%8F%E5%8D%A6%5D&#43;%E5%BB%B6%E7%A6%A7%E6%94%BB%E7%95%A5%E7%9C%8B%E4%B8%8D%E4%B8%8B%E5%8E%BB%E6%80%8E%E9%BA%BC%E8%BE%A6%3F">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Gossiping/search?q=author%3ATiiek">搜尋看板內 Tiiek 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date">10/10</div>
# 				<div class="mark"></div>
# 			</div>
# 		</div>
#
#
#
#         <div class="r-list-sep"></div>
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f2">1</span></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1510415718.A.D77.html">[公告] 八卦板板規(2017.11.11)</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">Kay731</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%85%AC%E5%91%8A%5D&#43;%E5%85%AB%E5%8D%A6%E6%9D%BF%E6%9D%BF%E8%A6%8F%282017.11.11%29">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Gossiping/search?q=author%3AKay731">搜尋看板內 Kay731 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date">11/11</div>
# 				<div class="mark">!</div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f1">爆</span></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1538319270.A.13E.html">[公告] 政問罰則暫時提高至16個月</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">RandyMarsh</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%85%AC%E5%91%8A%5D&#43;%E6%94%BF%E5%95%8F%E7%BD%B0%E5%89%87%E6%9A%AB%E6%99%82%E6%8F%90%E9%AB%98%E8%87%B316%E5%80%8B%E6%9C%88">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Gossiping/search?q=author%3ARandyMarsh">搜尋看板內 RandyMarsh 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date"> 9/30</div>
# 				<div class="mark">M</div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f3">93</span></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1538323290.A.B6E.html">[公告] 十月置底閒聊聊天文</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">RandyMarsh</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%85%AC%E5%91%8A%5D&#43;%E5%8D%81%E6%9C%88%E7%BD%AE%E5%BA%95%E9%96%92%E8%81%8A%E8%81%8A%E5%A4%A9%E6%96%87">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Gossiping/search?q=author%3ARandyMarsh">搜尋看板內 RandyMarsh 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date">10/01</div>
# 				<div class="mark">M</div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f3">17</span></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1538921259.A.576.html">[協尋] 107/10/05 13:50台中公正路英才路段車禍</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">q521q522</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%8D%94%E5%B0%8B%5D&#43;107%2F10%2F05&#43;13%3A50%E5%8F%B0%E4%B8%AD%E5%85%AC%E6%AD%A3%E8%B7%AF%E8%8B%B1%E6%89%8D%E8%B7%AF%E6%AE%B5%E8%BB%8A%E7%A6%8D">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Gossiping/search?q=author%3Aq521q522">搜尋看板內 q521q522 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date">10/07</div>
# 				<div class="mark"></div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f3">19</span></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1539159328.A.3DA.html">[公告] =姆咪=八卦板主徵選報名開始=姆咪=</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">jacklyl</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%85%AC%E5%91%8A%5D&#43;%3D%E5%A7%86%E5%92%AA%3D%E5%85%AB%E5%8D%A6%E6%9D%BF%E4%B8%BB%E5%BE%B5%E9%81%B8%E5%A0%B1%E5%90%8D%E9%96%8B%E5%A7%8B%3D%E5%A7%86%E5%92%AA%3D">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Gossiping/search?q=author%3Ajacklyl">搜尋看板內 jacklyl 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date">10/10</div>
# 				<div class="mark">M</div>
# 			</div>
# 		</div>
#
#
#
# 	</div>
#
#
# <div class="bbs-screen bbs-footer-message">本網站已依台灣網站內容分級規定處理。此區域為限制級，未滿十八歲者不得瀏覽。</div>
#
# </div>
#
#
#
# <script>
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-32365737-1', {
#     cookieDomain: 'ptt.cc',
#     legacyCookieDomain: 'ptt.cc'
#   });
#   ga('send', 'pageview');
# </script>
#
#
#
# <script src="//ajax.googleapis.com/ajax/libs/jquery/2.1.1/jquery.min.js"></script>
# <script src="//images.ptt.cc/bbs/v2.25/bbs.js"></script>
#
#     </body>
# </html>

# %% [markdown]
# ##### 2.1.4.2 Using Scrapy

# %%
import scrapy
from scrapy.http import Request, FormRequest
from scrapy.crawler import CrawlerProcess

class Spider(scrapy.Spider):
    name="ptt"
    
    def start_requests(self):
        yield Request(url='https://www.ptt.cc/ask/over18',cookies={'Cookie':'over18=1','User-Agent':'Mozilla/5.0'},callback=self.login)
        
    def login(self, response):
        yield FormRequest.from_response(
            response,
            formdata={'yes':'yes','from':'/bbs/Gossiping/'},
            callback=self.parse
        )
        
    def parse(self,response):
        print(response.text)
        
        
process = CrawlerProcess()
process.crawl(Spider)
process.start()
# Out:
# 2018-10-10 21:04:30 [scrapy.utils.log] INFO: Scrapy 1.5.1 started (bot: scrapybot)
# 2018-10-10 21:04:30 [scrapy.utils.log] INFO: Versions: lxml 4.2.1.0, libxml2 2.9.8, cssselect 1.0.3, parsel 1.5.0, w3lib 1.19.0, Twisted 18.7.0, Python 3.6.5 |Anaconda, Inc.| (default, Apr 26 2018, 08:42:37) - [GCC 4.2.1 Compatible Clang 4.0.1 (tags/RELEASE_401/final)], pyOpenSSL 18.0.0 (OpenSSL 1.0.2o  27 Mar 2018), cryptography 2.2.2, Platform Darwin-17.7.0-x86_64-i386-64bit
# 2018-10-10 21:04:30 [scrapy.crawler] INFO: Overridden settings: {}
# 2018-10-10 21:04:30 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.logstats.LogStats']
# 2018-10-10 21:04:30 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2018-10-10 21:04:30 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2018-10-10 21:04:30 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2018-10-10 21:04:30 [scrapy.core.engine] INFO: Spider opened
# 2018-10-10 21:04:30 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2018-10-10 21:04:30 [scrapy.extensions.telnet] DEBUG: Telnet console listening on 127.0.0.1:6023
# 2018-10-10 21:04:31 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.ptt.cc/ask/over18> (referer: None)
# 2018-10-10 21:04:31 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (302) to <GET https://www.ptt.cc/bbs/Gossiping/> from <POST https://www.ptt.cc/ask/over18>
# 2018-10-10 21:04:31 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (302) to <GET https://www.ptt.cc/bbs/Gossiping/index.html> from <GET https://www.ptt.cc/bbs/Gossiping/>
# 2018-10-10 21:04:31 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.ptt.cc/bbs/Gossiping/index.html> (referer: https://www.ptt.cc/ask/over18)
# 2018-10-10 21:04:31 [scrapy.core.engine] INFO: Closing spider (finished)
# 2018-10-10
的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date">10/10</div>
# 				<div class="mark"></div>
# 			</div>
# 		</div>
#
#
#
#         <div class="r-list-sep"></div>
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f2">1</span></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1510415718.A.D77.html">[公告] 八卦板板規(2017.11.11)</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">Kay731</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%85%AC%E5%91%8A%5D&#43;%E5%85%AB%E5%8D%A6%E6%9D%BF%E6%9D%BF%E8%A6%8F%282017.11.11%29">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Gossiping/search?q=author%3AKay731">搜尋看板內 Kay731 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date">11/11</div>
# 				<div class="mark">!</div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f1">爆</span></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1538319270.A.13E.html">[公告] 政問罰則暫時提高至16個月</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">RandyMarsh</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%85%AC%E5%91%8A%5D&#43;%E6%94%BF%E5%95%8F%E7%BD%B0%E5%89%87%E6%9A%AB%E6%99%82%E6%8F%90%E9%AB%98%E8%87%B316%E5%80%8B%E6%9C%88">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Gossiping/search?q=author%3ARandyMarsh">搜尋看板內 RandyMarsh 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date"> 9/30</div>
# 				<div class="mark">M</div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f3">93</span></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1538323290.A.B6E.html">[公告] 十月置底閒聊聊天文</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">RandyMarsh</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%85%AC%E5%91%8A%5D&#43;%E5%8D%81%E6%9C%88%E7%BD%AE%E5%BA%95%E9%96%92%E8%81%8A%E8%81%8A%E5%A4%A9%E6%96%87">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Gossiping/search?q=author%3ARandyMarsh">搜尋看板內 RandyMarsh 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date">10/01</div>
# 				<div class="mark">M</div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f3">17</span></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1538921259.A.576.html">[協尋] 107/10/05 13:50台中公正路英才路段車禍</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">q521q522</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%8D%94%E5%B0%8B%5D&#43;107%2F10%2F05&#43;13%3A50%E5%8F%B0%E4%B8%AD%E5%85%AC%E6%AD%A3%E8%B7%AF%E8%8B%B1%E6%89%8D%E8%B7%AF%E6%AE%B5%E8%BB%8A%E7%A6%8D">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Gossiping/search?q=author%3Aq521q522">搜尋看板內 q521q522 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date">10/07</div>
# 				<div class="mark"></div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f3">19</span></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1539159328.A.3DA.html">[公告] =姆咪=八卦板主徵選報名開始=姆咪=</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">jacklyl</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%85%AC%E5%91%8A%5D&#43;%3D%E5%A7%86%E5%92%AA%3D%E5%85%AB%E5%8D%A6%E6%9D%BF%E4%B8%BB%E5%BE%B5%E9%81%B8%E5%A0%B1%E5%90%8D%E9%96%8B%E5%A7%8B%3D%E5%A7%86%E5%92%AA%3D">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Gossiping/search?q=author%3Ajacklyl">搜尋看板內 jacklyl 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date">10/10</div>
# 				<div class="mark">M</div>
# 			</div>
# 		</div>
#
#
#
# 	</div>
#
#
# <div class="bbs-screen bbs-footer-message">本網站已依台灣網站內容分級規定處理。此區域為限制級，未滿十八歲者不得瀏覽。</div>
#
# </div>
#
#
#
# <script>
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-32365737-1', {
#     cookieDomain: 'ptt.cc',
#     legacyCookieDomain: 'ptt.cc'
#   });
#   ga('send', 'pageview');
# </script>
#
#
#
# <script src="//ajax.googleapis.com/ajax/libs/jquery/2.1.1/jquery.min.js"></script>
# <script src="//images.ptt.cc/bbs/v2.25/bbs.js"></script>
#
#     </body>
# </html>

# %%
import scrapy
from scrapy.http import Request, FormRequest
from scrapy.crawler import CrawlerProcess

class Spider(scrapy.Spider):
    name="ptt"
    
    def start_requests(self):
        yield Request(url='https://www.ptt.cc/ask/over18',cookies={'Cookie':'over18=1','User-Agent':'Mozilla/5.0'},callback=self.login)
        
    def login(self, response):
        yield FormRequest.from_response(
            response,
            formdata={'yes':'yes','from':'/bbs/Gossiping/'},
            callback=self.parse
        )
        
    def parse(self,response):
        print(response.text)
        
        
process = CrawlerProcess()
process.crawl(Spider)
process.start()
# Out:
# 2018-10-10 21:07:10 [scrapy.utils.log] INFO: Scrapy 1.5.1 started (bot: scrapybot)
# 2018-10-10 21:07:10 [scrapy.utils.log] INFO: Versions: lxml 4.2.1.0, libxml2 2.9.8, cssselect 1.0.3, parsel 1.5.0, w3lib 1.19.0, Twisted 18.7.0, Python 3.6.5 |Anaconda, Inc.| (default, Apr 26 2018, 08:42:37) - [GCC 4.2.1 Compatible Clang 4.0.1 (tags/RELEASE_401/final)], pyOpenSSL 18.0.0 (OpenSSL 1.0.2o  27 Mar 2018), cryptography 2.2.2, Platform Darwin-17.7.0-x86_64-i386-64bit
# 2018-10-10 21:07:10 [scrapy.crawler] INFO: Overridden settings: {}
# 2018-10-10 21:07:10 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.logstats.LogStats']
# 2018-10-10 21:07:10 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2018-10-10 21:07:10 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2018-10-10 21:07:10 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2018-10-10 21:07:10 [scrapy.core.engine] INFO: Spider opened
# 2018-10-10 21:07:10 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2018-10-10 21:07:10 [scrapy.extensions.telnet] DEBUG: Telnet console listening on 127.0.0.1:6023
# 2018-10-10 21:07:10 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.ptt.cc/ask/over18> (referer: None)
# 2018-10-10 21:07:10 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (302) to <GET https://www.ptt.cc/bbs/Gossiping/> from <POST https://www.ptt.cc/ask/over18>
# 2018-10-10 21:07:10 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (302) to <GET https://www.ptt.cc/bbs/Gossiping/index.html> from <GET https://www.ptt.cc/bbs/Gossiping/>
# 2018-10-10 21:07:11 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.ptt.cc/bbs/Gossiping/index.html> (referer: https://www.ptt.cc/ask/over18)
# 2018-10-10 21:07:11 [scrapy.core.engine] INFO: Closing spider (finished)
# 2018-10-10 21:07:11 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 1394,
#  'downloader/request_count': 4,
#  'downloader/request_method_count/GET': 3,
#  'downloader/request_method_count/POST': 1,
#  'downloader/response_bytes': 7936,
#  'downloader/response_count': 4,
#  'downloader/response_status_count/200': 2,
#  'downloader/response_status_count/302': 2,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2018, 10, 10, 13, 7, 11, 138992),
#  'log_count/DEBUG': 5,
#  'log_count/INFO': 7,
#  'memusage/max': 69701632,
#  'memusage/startup': 69701632,
#  'request_depth_max': 1,
#  'response_received_count': 2,
#  'scheduler/dequeued': 4,
#  'scheduler/dequeued/memory': 4,
#  'scheduler/enqueued': 4,
#  'scheduler/enqueued/memory': 4,
#  'start_time': datetime.datetime(2018, 10, 10, 13, 7, 10, 290699)}
# 2018-10-10 21:07:11 [scrapy.core.engine] INFO: Spider closed (finished)
# <!DOCTYPE html>
# <html>
# 	<head>
# 		<meta charset="utf-8">
#
#
# <meta name="viewport" content="width=device-width, initial-scale=1">
#
# <title>看板 Gossiping 文章列表 - 批踢踢實業坊</title>
#
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.25/bbs-common.css">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.25/bbs-base.css" media="screen">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.25/bbs-custom.css">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.25/pushstream.css" media="screen">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.25/bbs-print.css" media="print">
#
#
#
#
# 	</head>
#     <body>
#
# <div id="topbar-container">
# 	<div id="topbar" class="bbs-content">
# 		<a id="logo" href="/bbs/">批踢踢實業坊</a>
# 		<span>&rsaquo;</span>
# 		<a class="board" href="/bbs/Gossiping/index.html"><span class="board-label">看板 </span>Gossiping</a>
# 		<a class="right small" href="/about.html">關於我們</a>
# 		<a class="right small" href="/contact.html">聯絡資訊</a>
# 	</div>
# </div>
#
# <div id="main-container">
# 	<div id="action-bar-container">
# 		<div class="action-bar">
# 			<div class="btn-group btn-group-dir">
# 				<a class="btn selected" href="/bbs/Gossiping/index.html">看板</a>
# 				<a class="btn" href="/man/Gossiping/index.html">精華區</a>
# 			</div>
# 			<div class="btn-group btn-group-paging">
# 				<a class="btn wide" href="/bbs/Gossiping/index1.html">最舊</a>
# 				<a class="btn wide" href="/bbs/Gossiping/index39201.html">&lsaquo; 上頁</a>
# 				<a class="btn wide disabled">下頁 &rsaquo;</a>
# 				<a class="btn wide" href="/bbs/Gossiping/index.html">最新</a>
# 			</div>
# 		</div>
# 	</div>
#
# 	<div class="r-list-container action-bar-margin bbs-screen">
# 		<div class="search-bar">
# 			<form type="get" action="search" id="search-bar">
# 				<input class="query" type="text" name="q" value="" placeholder="搜尋文章&#x22ef;">
# 			</form>
# 		</div>
#
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f3">14</span></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1539176115.A.BC0.html">[問卦] 朋友狗被殺了該怎麼安慰他 </a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">KSHLO</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%95%8F%E5%8D%A6%5D&#43;%E6%9C%8B%E5%8F%8B%E7%8B%97%E8%A2%AB%E6%AE%BA%E4%BA%86%E8%A9%B2%E6%80%8E%E9%BA%BC%E5%AE%89%E6%85%B0%E4%BB%96&#43;">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Gossiping/search?q=author%3AKSHLO">搜尋看板內 KSHLO 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date">10/10</div>
# 				<div class="mark"></div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1539176118.A.F3A.html">Re: [新聞] 挺韓國瑜青年戰舞影片曝光 鄉民看完笑翻</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">DICB</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E6%96%B0%E8%81%9E%5D&#43;%E6%8C%BA%E9%9F%93%E5%9C%8B%E7%91%9C%E9%9D%92%E5%B9%B4%E6%88%B0%E8%88%9E%E5%BD%B1%E7%89%87%E6%9B%9D%E5%85%89&#43;%E9%84%89%E6%B0%91%E7%9C%8B%E5%AE%8C%E7%AC%91%E7%BF%BB">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Gossiping/search?q=author%3ADICB">搜尋看板內 DICB 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date">10/10</div>
# 				<div class="mark"></div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1539176142.A.7F9.html">[問卦] 排嗡嗡包的有多少是台北市人?</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">Blacky5566</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%95%8F%E5%8D%A6%5D&#43;%E6
a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">RandyMarsh</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%85%AC%E5%91%8A%5D&#43;%E6%94%BF%E5%95%8F%E7%BD%B0%E5%89%87%E6%9A%AB%E6%99%82%E6%8F%90%E9%AB%98%E8%87%B316%E5%80%8B%E6%9C%88">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Gossiping/search?q=author%3ARandyMarsh">搜尋看板內 RandyMarsh 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date"> 9/30</div>
# 				<div class="mark">M</div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f3">93</span></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1538323290.A.B6E.html">[公告] 十月置底閒聊聊天文</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">RandyMarsh</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%85%AC%E5%91%8A%5D&#43;%E5%8D%81%E6%9C%88%E7%BD%AE%E5%BA%95%E9%96%92%E8%81%8A%E8%81%8A%E5%A4%A9%E6%96%87">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Gossiping/search?q=author%3ARandyMarsh">搜尋看板內 RandyMarsh 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date">10/01</div>
# 				<div class="mark">M</div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f3">17</span></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1538921259.A.576.html">[協尋] 107/10/05 13:50台中公正路英才路段車禍</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">q521q522</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%8D%94%E5%B0%8B%5D&#43;107%2F10%2F05&#43;13%3A50%E5%8F%B0%E4%B8%AD%E5%85%AC%E6%AD%A3%E8%B7%AF%E8%8B%B1%E6%89%8D%E8%B7%AF%E6%AE%B5%E8%BB%8A%E7%A6%8D">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Gossiping/search?q=author%3Aq521q522">搜尋看板內 q521q522 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date">10/07</div>
# 				<div class="mark"></div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f3">19</span></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1539159328.A.3DA.html">[公告] =姆咪=八卦板主徵選報名開始=姆咪=</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">jacklyl</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%85%AC%E5%91%8A%5D&#43;%3D%E5%A7%86%E5%92%AA%3D%E5%85%AB%E5%8D%A6%E6%9D%BF%E4%B8%BB%E5%BE%B5%E9%81%B8%E5%A0%B1%E5%90%8D%E9%96%8B%E5%A7%8B%3D%E5%A7%86%E5%92%AA%3D">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Gossiping/search?q=author%3Ajacklyl">搜尋看板內 jacklyl 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date">10/10</div>
# 				<div class="mark">M</div>
# 			</div>
# 		</div>
#
#
#
# 	</div>
#
#
# <div class="bbs-screen bbs-footer-message">本網站已依台灣網站內容分級規定處理。此區域為限制級，未滿十八歲者不得瀏覽。</div>
#
# </div>
#
#
#
# <script>
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-32365737-1', {
#     cookieDomain: 'ptt.cc',
#     legacyCookieDomain: 'ptt.cc'
#   });
#   ga('send', 'pageview');
# </script>
#
#
#
# <script src="//ajax.googleapis.com/ajax/libs/jquery/2.1.1/jquery.min.js"></script>
# <script src="//images.ptt.cc/bbs/v2.25/bbs.js"></script>
#
#     </body>
# </html>

# %% [markdown]
# ### 2.2 Selenium

# %%
# !pip install selenium

# %%
from selenium import webdriver
URI='https://www.ptt.cc/bbs/Gossiping/'
driver=webdriver.Chrome()
driver.get(URI)
btn=driver.find_element_by_name('yes')
driver.save_screenshot('before_click.png')
btn.click()
driver.save_screenshot('after_click.png')
print(driver.page_source)
# Out:
# 2018-10-10 21:22:23 [selenium.webdriver.remote.remote_connection] DEBUG: POST http://127.0.0.1:53548/session {"capabilities": {"firstMatch": [{}], "alwaysMatch": {"browserName": "chrome", "platformName": "any", "goog:chromeOptions": {"extensions": [], "args": []}}}, "desiredCapabilities": {"browserName": "chrome", "version": "", "platform": "ANY", "goog:chromeOptions": {"extensions": [], "args": []}}}
# 2018-10-10 21:22:23 [urllib3.connectionpool] DEBUG: Starting new HTTP connection (1): 127.0.0.1
# 2018-10-10 21:22:24 [urllib3.connectionpool] DEBUG: http://127.0.0.1:53548 "POST /session HTTP/1.1" 200 795
# 2018-10-10 21:22:24 [selenium.webdriver.remote.remote_connection] DEBUG: Finished Request
# 2018-10-10 21:22:24 [selenium.webdriver.remote.remote_connection] DEBUG: POST http://127.0.0.1:53548/session/055927f341eaacbe17f9c586fc13df4f/url {"url": "https://www.ptt.cc/bbs/Gossiping/", "sessionId": "055927f341eaacbe17f9c586fc13df4f"}
# 2018-10-10 21:22:24 [urllib3.connectionpool] DEBUG: Resetting dropped connection: 127.0.0.1
# 2018-10-10 21:22:25 [urllib3.connectionpool] DEBUG: http://127.0.0.1:53548 "POST /session/055927f341eaacbe17f9c586fc13df4f/url HTTP/1.1" 200 72
# 2018-10-10 21:22:25 [selenium.webdriver.remote.remote_connection] DEBUG: Finished Request
# 2018-10-10 21:22:25 [selenium.webdriver.remote.remote_connection] DEBUG: POST http://127.0.0.1:53548/session/055927f341eaacbe17f9c586fc13df4f/element {"using": "name", "value": "yes", "sessionId": "055927f341eaacbe17f9c586fc13df4f"}
# 2018-10-10 21:22:25 [urllib3.connectionpool] DEBUG: Resetting dropped connection: 127.0.0.1
# 2018-10-10 21:22:25 [urllib3.connectionpool] DEBUG: http://127.0.0.1:53548 "POST /session/055927f341eaacbe17f9c586fc13df4f/element HTTP/1.1" 200 101
# 2018-10-10 21:22:25 [selenium.webdriver.remote.remote_connection] DEBUG: Finished Request
# 2018-10-10 21:22:25 [selenium.webdriver.remote.remote_connection] DEBUG: GET http://127.0.0.1:53548/session/055927f341eaacbe17f9c586fc13df4f/screenshot {"sessionId": "055927f341eaacbe17f9c586fc13df4f"}
# 2018-10-10 21:22:25 [urllib3.connectionpool] DEBUG: Resetting dropped connection: 127.0.0.1
# 2018-10-10 21:22:26 [urllib3.connectionpool] DEBUG: http://127.0.0.1:53548 "GET /session/055927f341eaacbe17f9c586fc13df4f/screenshot HTTP/1.1" 200 125634
# 2018-10-10 21:22:26 [selenium.webdriver.remote.remote_connection] DEBUG: Finished Request
# 