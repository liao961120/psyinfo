# %% [markdown]
# ## 「科學、科技」讓人想高談闊論？
#
# ### 假設
#
# 與科學、科技相關的 Youtube 影片，可能會觸發觀眾對於科學、科技的 schema，例如，批判性思考、辯論等，
# 因此，可能較其它類別更容易引起觀眾留言的欲望
#
# ### 方法
#
# 擷取不同類別的熱門影片(「科學與科技(Science & Technology)」 vs. 「娛樂(entertainment)」)，
# 比較兩者**留言比例**，看「科學與科技」的類別之觀眾是否真的比較喜歡留言。
#
# #### 定義
#
# 留言比例
# :

# %%
DEVELOPER_KEY = "AIzaSyBrYL6pEvJxTALro2sEXB1f0CKCcZRRKxk"
YOUTUBE_API_SERVICE_NAME = "youtube"
YOUTUBE_API_VERSION = "v3"

def videos_most_pop(maxResults=2, region=None, category=None):
    youtube = build(YOUTUBE_API_SERVICE_NAME, YOUTUBE_API_VERSION, developerKey=DEVELOPER_KEY)  
    response = youtube.videos().list(
        part='id,snippet,contentDetails, statistics',
        chart='mostPopular',
        regionCode=region, # 'TW'
        videoCategoryId=category, # string
        maxResults=maxResults).execute()

    return response

# %%
def construct_df(x):
    import pandas as pd
    
    l = len(x['items'])
    ID = ['s']*l
    title = ['s']*l
    category = ['s']*l
    datetime = ['s']*l
    duration = ['s']*l
    quality = ['s']*l
    view = [0]*l
    like = [0]*l
    comment = [0]*l

    for i in range(l):
        ID[i] = x['items'][i]['id']

        snippet = x['items'][i]['snippet']
        title[i] = snippet['title']
        category[i] = snippet['categoryId']
        datetime[i] = snippet['publishedAt']

        video_info = x['items'][i]['contentDetails']
        duration = video_info['duration']
        quality = video_info['definition']

        stats = x['items'][i]['statistics'] # statisitcs dict
        view[i] = stats['viewCount']
        like[i] = stats['likeCount']
        comment[i] = stats['commentCount']

    df = pd.DataFrame(
        {"ID": ID,
         "title" : title,
         "category" : category,
         "datetime" : datetime,
         "duration" : duration,
         "quality" : quality,
         "view" : view,
         "like" : like,
         "comment" : comment}
    )
    
    return df

# %%
# Science and Technology category
sci = videos_most_pop(maxResults=100, category='28')
sci_df = construct_df(sci)
sci_df['comment_rate'] = pd.to_numeric(sci_df.comment)/pd.to_numeric(sci_df.view) # calculate new column
sci_df.head()
# Out:
#             ID                                              title category  \
# 0  Cb1phBbBMCs  FOUND PROJECT ZORGO MYSTERIOUS LABORATORY (Esc...       26
# 1  0kzNZkCszho              Try Not To Feel Good Challenge Part 2       22
# 2  339-l2cO0pM           SURPRISING MOM WITH WELL DESERVED GIFT!!       22
# 3  SAznk7rZ6BY                                             IMMURE       20
# 4  MFkk0kj4eoA                  Wish.com Haul ($15 SMART WATCH??)       24
#
#                    datetime  duration quality     view    like comment
# 0  2018-10-06T17:16:14.000Z  PT10M42S      hd  1491928   36432   32869
# 1  2018-10-02T19:15:01.000Z  PT10M42S      hd  3499534   37299   12526
# 2  2018-10-06T09:01:18.000Z  PT10M42S      hd  3200681  325718   12685
# 3  2018-10-05T18:00:03.000Z  PT10M42S      hd   739330   32282    3295
# 4  2018-10-05T10:00:04.000Z  PT10M42S      hd   346133    8788    1116

# %%
# Entertainment category
entertain = videos_most_pop(maxResults=100, category='24')
entertain_df = construct_df(entertain)
entertain_df['comment_rate'] = pd.to_numeric(entertain_df.comment)/pd.to_numeric(entertain_df.view) # calculate new column
entertain_df.head()
# Out:
#              ID                                              title category  \
# 0   VRJecfRxbr8                  Kavanaugh Hearing Cold Open - SNL       24
# 1   rvUzuK0ygI4                                     Tabletop Games       23
# 2   tg52up16eq0  SPIDER-MAN: INTO THE SPIDER-VERSE - Official T...       24
# 3   Hon5Y13M3oA                           The Enemies of Jake Paul       23
# 4   TPTdxGTX0vw  DIY EDIBLE SCHOOL SUPPLIES! Teacher vs  Suppli...       23
# 5   opi8X9hQ7q8  Brett Kavanaugh: Last Week Tonight with John O...       24
# 6   Trut3uXDXk0                     Wish.com vs. Name Brand (GAME)       24
# 7   wwWWPFPutNk  PROJECT ZORGO DOOMSDAY DATE CLUES (Solving Esc...       26
# 8   1Q9gyywpuug           SML Movie: Bowser Junior's Walkie Talkie       24
# 9   B1WMNP6NY6s  Chrissy Teigen Gets Drunk on Spicy Wings | Hot...       26
# 10  5Ji8i7Wy4mo  EXCLUSIVE - Stormy Daniels Details Sex with Do...       24
# 11  hYGthjj_Wuk  PROJECT ZORGO TOOK OFF HIS MASK! (Mystery Box ...       24
# 12  -M7kcJr8QY0  Everything Wrong With Deadpool 2 In 19 Minutes...        1
# 13  CpYgDTimaKs  Brett Kavanaugh’s 1985 Bar Brawl Brings His Ho...       23
# 14  riAS1lvDA4k  Fortnite: The Squad | Battle Royale Compilatio...       20
# 15  6n8FTIWlyXY  Stephen Does The Math On Senators For/Against ...       24
# 16  _frZbfgaNnw  MYSTERY WHEEL Controls My Life w/GIRLFRIEND!! ...       23
# 17  T_o6BmTb48A  Lil Wayne Talks Tha Carter V and Memorizing Hi...       23
# 18  CazC8lr08wY  Trump Melts Down over Dr. Ford's Testimony: A ...       23
# 19  q0G-qLlIans                                         𝓜𝓸𝓽𝓱 𝓜𝓮𝓶𝓮𝓼       24
# 20  sPSd7omV7QE     HIS WIFE WAS NOT HAPPY ABOUT THIS!! (SURPRISE)       22
# 21  NANnk3yFz5c             UNBOXING a $1000 Fortnite Mystery Box!       24
# 22  gFnrqjcHTps                               DEAR SHANE DAWSON...       24
# 23  7dqkMSM2vFk  YouTubes BIGGEST SCAM! #DramaAlert Shane Dawso...       25
# 24  GNQ8GoRKo2g                 UNDERWATER DATE WITH MY CRUSH!! ❤️       24
# 25  ybKUX6thF8Q  Chilling Adventures of Sabrina | Official Trai...       24
# 26  UuP3ErzNoys  THE GAME MASTER FOUND US!! (ABANDONED SAFE HOU...       24
# 27  QlIXpibXR3A                                 Bad YouTuber Music       22
# 28  wDqJZ_2ZA3A    I Spent $30,000 On Lottery Tickets And Won ____       24
# 29  3Zou1J4jiMo               WE DROPPED HER PHONE OFF A BUILDING!       22
# 30  IdQ_sYuIEPU            Stunt Jumps Through Impossible Shapes!!       23
# 31  -GwFOWxVr4w  Overtime: Doris Goodwin, Jeff Bridges, Soledad...        1
# 32  jUqZNp0gphM  10 Magic Products Magicians Don't Want You To ...       23
# 33  gr0y26dveAw  T.I. Talks New Album 'Dime Trap', Curating Tra...       24
# 34  4l1KmosqKL4  Solving The Doomsday Date by Project Zorgo (Ab...       27
# 35  RpUtIeCf9K0                PARENTS IN 1998 vs. PARENTS IN 2018       23
# 36  gDz9EROrbAM         You Will REGRET LAUGHING At This... (YLYL)       20
# 37  WaWnLiffxJ4  AQUAMAN – Extended Video – Only in Theaters De...       24
# 38  XBPV9putsfc             The Try Guys' Surprise Office Makeover       23
# 39  9j73Nu2eEn4                    This made Molly want me back...       24
# 40  lfqVBUy4DAE  Rhett & Link Answer the Web's Most Searched Qu...       24
# 41  G-aEU3TFjU8  REWARD! Doomsday Date Password Solving Wanted ...       28
# 42  QWbMckU3AOQ  Dark Phoenix | Official Trailer [HD] | 20th Ce...        1
# 43  o_BdYDrGll0  Woman Defends 2 Spanish Speakers Harassed at C...       25
# 44  6Mjb6_MT-qc  Fan Bingbing's Mysterious Disappearance, Presi...       25
# 45  ePpmJp-wb0Y                      I've Been Hacked! | Lele Pons       23
# 46  mzwOKjYbgoo    #1 FIFA Player | Hannah Stocking & Anwar Jibawi       23
# 47  1ZbnrIHYsCE  Father & Daughter Get Put In the Hot Seat 🔥 | ...       24
# 48  PMz6DYrUrOc                        SCARY MONSTER STOLE MY CAR!       24
# 49  KpljzfIVBDM                  When Celebrities Lose Their Cool!       24
#
#                     datetime duration quality      view    like comment
# 0   2018-09-30T05:16:21.000Z  PT10M7S      hd  20166846  225221   64414
# 1   2018-10-05T17:34:31.000Z  PT10M7S      hd   5634557  354123   69915
# 2   2018-10-02T13:00:34.000Z  PT10M7S      hd  14528182  318401   34641
# 3   2018-10-03T19:00:00.000Z  PT10M7S      hd  12903256  900703  124600
# 4   2018-09-30T18:59:48.000Z  PT10M7S      hd   2822176   23952    3066
# 5   2018-10-01T06:30:01.000Z  PT10M7S      hd   6878807  141459   31839
# 6   2018-10-05T10:00:03.000Z  PT10M7S      hd   1796079   40105    3955
# 7   2018-10-03T21:46:02.000Z  PT10M7S      hd   4228156   96903   27950
# 8   2018-10-02T23:15:04.000Z  PT10M7S      hd   2697848   50711   25066
# 9   2018-10-04T15:00:01.000Z  PT10M7S      hd   2025866   54975   10725
# 10  2018-10-03T05:06:58.000Z  PT10M7S      hd   5435028   60544   25879
# 11  2018-10-06T15:58:00.000Z  PT10M7S      hd   2060547   90878   17103
# 12  2018-10-04T22:17:38.000Z  PT10M7S      hd   2851462   65571    6772
# 13  2018-10-03T00:56:46.000Z  PT10M7S      hd   2233025   32231    4426
# 14  2018-09-28T20:43:18.000Z  PT10M7S      hd   5858182   71509    3951
# 15  2018-10-05T04:11:03.000Z  PT10M7S      hd   2003620   26861    5375
# 16  2018-10-01T17:24:12.000Z  PT10M7S      hd   4080703  268095   29020
# 17  2018-10-03T08:00:00.000Z  PT10M7S      hd   2790289   59015    8724
# 18  2018-10-04T01:00:02.000Z  PT10M7S      hd   1775711   22014    3531
# 19  2018-10-02T17:54:26.000Z  PT10M7S      hd   4449790  366705   30306
# 20  2018-10-04T07:59:32.000Z  PT10M7S      hd   4199612  290437    9684
# 21  2018-10-04T21:07:11.000Z  PT10M7S      hd   1538023   22299    5056
# 22  2018-09-30T16:36:32.000Z  PT10M7S      hd   5039697  191766   76955
# 23  2018-10-04T00:10:29.000Z  PT10M7S      hd   1969760   77081    8454
# 24  2018-09-30T15:23:16.000Z  PT10M7S      hd   4735671   42815   14779
# 25  2018-10-03T14:30:09.000Z  PT10M7S      hd   2767746   78106    7241
# 26  2018-10-05T19:09:03.000Z  PT10M7S      hd   1067360   14624    4249
# 27  2018-10-05T16:30:53.000Z  PT10M7S      hd   1006228   92603    7305
# 28  2018-09-28T21:05:00.000Z  PT10M7S      hd   8788361  259078   21541
# 29  2018-10-06T18:01:24.000Z  PT10M7S      hd    641831   21959    2944
# 30  2018-09-28T20:16:24.000Z  PT10M7S      hd   4360272   43509    4458
# 31  2018-10-06T04:32:47.000Z  PT10M7S      hd    412607    4292    1722
# 32  2018-10-06T17:12:09.000Z  PT10M7S      hd    679840  100089   13915
# 33  2018-10-04T12:29:45.000Z  PT10M7S      hd    664657    9856    3108
# 34  2018-10-05T20:14:18.000Z  PT10M7S      hd   1584224   41107   14268
# 35  2018-10-03T16:00:05.000Z  PT10M7S      hd   1938797   59518    4060
# 36  2018-09-30T02:45:19.000Z  PT10M7S      hd   3663899  108414   17348
# 37  2018-10-05T15:47:00.000Z  PT10M7S      hd   4546366  130070   20457
# 38  2018-10-06T15:00:04.000Z  PT10M7S      hd   1384594  101914    5181
# 39  2018-10-04T22:52:59.000Z  PT10M7S      hd   1040117   53826   11432
# 40  2018-10-03T16:01:35.000Z  PT10M7S      hd   1398919   43899    2458
# 41  2018-10-03T18:21:10.000Z  PT10M7S      hd   1197211   13513   47598
# 42  2018-09-27T05:00:10.000Z  PT10M7S      hd  14189622  208373   27605
# 43  2018-10-05T21:27:43.000Z  PT10M7S      hd    445565   18762    5009
# 44  2018-10-03T21:54:11.000Z  PT10M7S      hd   1134189   44149    6552
# 45  2018-10-05T17:58:17.000Z  PT10M7S      hd   2898288   96582   10400
# 46  2018-09-28T16:01:56.000Z  PT10M7S      hd   3854274   66529    4970
# 47  2018-10-02T21:02:37.000Z  PT10M7S      hd   1247568   22823    1099
# 48  2018-10-04T21:33:56.000Z  PT10M7S      hd    987774   23122    5971
# 49  2018-09-25T21:46:43.000Z  PT10M7S      hd   4968925   54013    6174

# %%
sci_df.hist(column='comment_rate', bins=30, range=(0,0.05))
entertain_df.hist(column='comment_rate', bins=30, range=(0,0.05), color='green')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fc764692128>]],
#       dtype=object)

# %%
a = sum(sci_df.comment_rate > 0.01)/len(sci_df.comment_rate)
b = sum(entertain_df.comment_rate > 0.01)/len(entertain_df.comment_rate)
(a, b)
# Out:
# (0.36, 0.12)
